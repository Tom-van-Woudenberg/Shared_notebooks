# %% [markdown]
# # Interactive influence lines #

# %% [markdown]
# ![figuur 1](data/data_interactive_influence_lines/Structure_book.gif)

# %%
import sympy as sp

# %%
import numpy as np
import matplotlib.pylab as plt
from ipywidgets import widgets, interact

# %%
EI, x = sp.symbols('EI, x',real=True)

# %%
Bv, Cv, Cm = sp.symbols('Bv, Cv, Cm',real=True)
a, b, L1, L2 = sp.symbols('a, b, L1, L2',positive=True,real=True)
C1, C2, C3, C4 = sp.symbols('C1, C2, C3, C4')

# %% [markdown]
# # Find support reaction Av #

# %%
q = - Bv * sp.SingularityFunction(x,0,-1) - Cv * sp.SingularityFunction(x,L1,-1) + Cm * sp.SingularityFunction(x,L1,-2) + 1 * sp.SingularityFunction(x,a,-1)
V = -sp.integrate(q,x)+C1
M = sp.integrate(V,x)+C2
kappa = M / EI
phi = sp.integrate(kappa,x)+C3
w = sp.integrate(phi,x)+C4
eq1 = sp.Eq(V.subs(x,-1),0)
eq2 = sp.Eq(M.subs(x,-1),0)
eq3 = sp.Eq(w.subs(x,0),0)
eq4 = sp.Eq(w.subs(x,L1),0)
eq5 = sp.Eq(phi.subs(x,L1),0)
eq6 = sp.Eq(M.subs(x,L1+1),0)
eq7 = sp.Eq(V.subs(x,L1+1),0)
sol = sp.solve([eq1,eq2,eq3,eq4,eq5,eq6,eq7],[C1,C2,C3,C4,Bv, Cv, Cm])
Bv_sol = sol[Bv].rewrite(sp.Piecewise)
Bv_numpy = sp.lambdify([L1,a,EI],Bv_sol)
Cv_sol = sol[Cv].rewrite(sp.Piecewise)
Cv_numpy = sp.lambdify([L1,a,EI],Cv_sol)
Cm_sol = sol[Cm].rewrite(sp.Piecewise)
Cm_numpy = sp.lambdify([L1,a,EI],Cm_sol)
V_sol = V.subs(sol)
V_subs = V_sol.subs([(L1,10),(a,2.5),(EI,5000)])
V_numpy = sp.lambdify([L1,a,EI,x],V_sol.rewrite(sp.Piecewise))
M_sol = M.subs(sol)
M_subs = M_sol.subs([(L1,10),(a,2.5),(EI,5000)])
M_numpy = sp.lambdify([L1,a,EI,x],M_sol.rewrite(sp.Piecewise))

# %%
display(sp.simplify(Bv_sol.rewrite(sp.Piecewise)).expand().subs(a,x))
x_plot = np.linspace(0,10,1000)
plt.plot([0,10],[0,0],color='black',linewidth=2)
plt.plot(x_plot,Bv_numpy(L1=10,EI=5000,a=x_plot),color="blue")
plt.xlabel('$x_F$')
plt.ylabel('Influence factor support reaction at A')
axs = plt.gca()
axs.grid()
axs.invert_yaxis()
title0 = 'Influence lines for support reaction at A'
axs.set_title(title0);
# Out:
# Piecewise((1 - 3*x/(2*L1) + x**3/(2*L1**3), L1 > x), (0, True))

# %%
#q = - Bv * sp.SingularityFunction(x,0,-1) - Cv * sp.SingularityFunction(x,L1,-1) + Cm * sp.SingularityFunction(x,L1,-2) + 1 * sp.SingularityFunction(x,a,-1)
# V = -sp.integrate(q,x)+C1
# M = sp.integrate(V,x)+C2
# kappa = M / EI
# phi = sp.integrate(kappa,x)+C3
# w = sp.integrate(phi,x)+C4
# eq2 = sp.Eq(M.subs(x,0),0)
# eq3 = sp.Eq(w.subs(x,0),0)
# eq4 = sp.Eq(w.subs(x,L1),0)
# eq5 = sp.Eq(phi.subs(x,L1),0)
# sol = sp.solve([eq2,eq3,eq4,eq5],[C1,C2,C3,C4])
# V_sol = V.subs(sol)
# V_subs = V_sol.subs([(L1,10),(a,2.5),(EI,5000)])
# V_numpy = sp.lambdify([L1,a,EI,x],V_sol.rewrite(sp.Piecewise))
# M_sol = M.subs(sol)
# M_subs = M_sol.subs([(L1,10),(a,2.5),(EI,5000)])
# M_numpy = sp.lambdify([L1,a,EI,x],M_sol.rewrite(sp.Piecewise))

# %%
def func(b):
    x = np.linspace(0,10,100)
    fig, axs = plt.subplots(2, 1, figsize=(7, 6))
    axs[0].plot([0,10],[0,0],color='black',linewidth=2)
    axs[0].annotate(text='', xy=(0,0), xytext=(0,Bv_numpy(10,b,5000)), arrowprops=dict(arrowstyle='simple'))
    axs[0].annotate('%.2f kN' % Bv_numpy(10,b,5000),xy = [0.2,0.2])
    axs[0].annotate(text='', xy=(10,0), xytext=(10,Cv_numpy(10,b,5000)), arrowprops=dict(arrowstyle='simple'))
    axs[0].annotate(text='', xy=(10,0.5*Cm_numpy(10,b,5000)/-2), xytext=(10,-0.5*Cm_numpy(10,b,5000)/-2), arrowprops=dict(arrowstyle='simple',connectionstyle="arc3,rad=-.5"))
    axs[0].annotate(text='', xy=(b,0), xytext=(b,-1), arrowprops=dict(arrowstyle='simple'))
    axs[0].set_ylim([-1,1])
    axs[0].invert_yaxis()
    axs[0].axis('off')
    title0 = 'Free body diagram for unit load at $x_F = '+str(b)+'$'
    axs[0].set_title(title0)
    axs[1].plot([0,10],[0,0],color='black',linewidth=2)
    axs[1].grid()
    axs[1].axis('equal')
    axs[1].plot(x,Bv_numpy(10,x,5000),color='blue')
    axs[1].plot(b,Bv_numpy(10,b,5000),marker='o')
    axs[1].annotate('%.2f kN' % Bv_numpy(10,b,5000),xy = [b,Bv_numpy(10,b,5000)+0.4])
    axs[1].invert_yaxis()
    title1 = 'Influence line for support reaction at B'
    axs[1].set_title(title1)
    
interact(func, b = widgets.FloatSlider(min=0, max=10, value=2, step=0.2, description="Location unit load $x_F = $ ... (m)",readout_format='.1f',style= {'description_width': '180px'},layout = {'width': '400px'}) );
# Out:
# interactive(children=(FloatSlider(value=2.0, description='Location unit load $x_F = $ ... (m)', layout=Layout(…

# %% [markdown]
# ## Find M-line ##

# %%
display(sp.simplify(M_subs.rewrite(sp.Piecewise)))
x_plot = np.linspace(0,10,1000)
plt.plot([0,10],[0,0],color='black',linewidth=2)
plt.plot(x_plot,M_numpy(L1=10,a=2.5,EI=5000,x=x_plot),color="blue")
plt.xlabel('$x$')
plt.ylabel('Moment')
axs = plt.gca()
axs.grid()
axs.invert_yaxis()
title0 = 'Moment distribution for force at $x_F =  2.5 $'
axs.set_title(title0);
# Out:
# Piecewise((0, x > 10), (2.5 - 0.3671875*x, x > 2.5), (0.6328125*x, x > 0), (0, True))

# %% [markdown]
# ##  Finding influence line for M ##

# %%
q = 0
V = -sp.integrate(q,x)+C1
M = sp.integrate(V,x)+C2
kappa = M / EI
phi = sp.integrate(kappa,x)+C3 - sp.SingularityFunction(x,a,0)
w = sp.integrate(phi,x)+C4
eq2 = sp.Eq(M.subs(x,0),0)
eq3 = sp.Eq(w.subs(x,0),0)
eq4 = sp.Eq(w.subs(x,L1),0)
eq5 = sp.Eq(phi.subs(x,L1),0)
sol = sp.solve([eq2,eq3,eq4,eq5],[C1,C2,C3,C4])
w_sol = w.subs(sol)
w_subs = w_sol.subs([(L1,10),(a,2),(EI,5000)])
display(sp.simplify(w_subs.rewrite(sp.Piecewise)))
M_inf_numpy = sp.lambdify([L1,a,EI,x],w_sol.rewrite(sp.Piecewise))

x_plot = np.linspace(0,10,1000)
plt.plot([0,10],[0,0],color='black',linewidth=2)
plt.plot(x_plot,M_inf_numpy(L1=10,a=2.5,EI=5000,x=x_plot),color="blue")
plt.xlabel('$x_F$')
plt.ylabel('Influence factor moment')
axs = plt.gca()
axs.grid()
axs.invert_yaxis()
title0 = 'Influence line for moment at $x_M = 2.5$'
axs.set_title(title0);
# Out:
# Piecewise((x**3/1000 - 3*x/10 + 2, x > 2), (x*(x**2 + 700)/1000, True))

# %% [markdown]
# ## Comparison M-line and influence line for moment at $x = ...$ #

# %%
def func(a,b):
    x = np.linspace(0,10,100)
    fig, axs = plt.subplots(2, 1, figsize=(7, 6))
    axs[0].plot([0,10],[0,0],color='black',linewidth=2)
    axs[0].grid()
    axs[0].axis('equal')
    axs[0].plot(x,M_numpy(10,b,5000,x),color='blue')
    axs[0].plot(a,M_numpy(10,b,5000,a),marker='o')
    axs[0].annotate('%.2f kNm' % M_numpy(10,b,5000,a),xy = [a,M_numpy(10,b,5000,a)+0.5])
    axs[0].annotate(text='', xy=(b,0), xytext=(b,-1), arrowprops=dict(arrowstyle='simple'))
    axs[0].invert_yaxis()
    title0 = 'Moment distribution for force at $x_F = '+str(b)+'$, showing moment at $x_M = '+str(a)+'$'
    axs[0].set_title(title0)
    axs[1].plot([0,10],[0,0],color='black',linewidth=2)
    axs[1].grid()
    axs[1].axis('equal')
    axs[1].plot(x,M_inf_numpy(10,a,5000,x),color='blue')
    axs[1].plot(b,M_inf_numpy(10,a,5000,b),marker='o')
    axs[1].annotate('%.2f kNm' % M_inf_numpy(10,a,5000,b),xy = [b,M_inf_numpy(10,a,5000,b)+0.5])
    axs[1].invert_yaxis()
    title1 = 'Influence line for moment at $x_M = '+str(a)+'$'
    axs[1].set_title(title1)
    
interact(func, a = widgets.FloatSlider(min=0, max=10, value=2, step=0.2, description="Location moment $x_M =$ ... (m)",readout_format='.1f',style= {'description_width': '180px'},layout = {'width': '400px'}),
         b = widgets.FloatSlider(min=0, max=10, value=2, step=0.2, description="Location unit load $x_F = $ ... (m)",readout_format='.1f',style= {'description_width': '180px'},layout = {'width': '400px'}) );
# Out:
# interactive(children=(FloatSlider(value=2.0, description='Location moment $x_M =$ ... (m)', layout=Layout(widt…

# %% [markdown]
# # Find V-line #

# %%
display(sp.simplify(V_subs.rewrite(sp.Piecewise)))
x_plot = np.linspace(0,10.00001,1000)
plt.plot([0,10],[0,0],color='black',linewidth=2)
plt.plot(x_plot,V_numpy(L1=10,a=2.5,EI=5000,x=x_plot),color="blue")
plt.xlabel('$x$')
plt.ylabel('Shear force')
axs = plt.gca()
axs.grid()
axs.invert_yaxis()
title0 = 'Shear force distribution for force at $x_F =  2 $'
axs.set_title(title0);
# Out:
# Piecewise((0, x > 10), (oo, Eq(x, 10)), (-0.3671875, x > 2.5), (0.6328125, x > 0), (0, True))

# %% [markdown]
# ## Find influence line V ##

# %%
q = 0
V = -sp.integrate(q,x)+C1
M = sp.integrate(V,x)+C2
kappa = M / EI
phi = sp.integrate(kappa,x)+C3 
w = sp.integrate(phi,x)+C4 + sp.SingularityFunction(x,a,0)
eq2 = sp.Eq(M.subs(x,0),0)
eq3 = sp.Eq(w.subs(x,0),0)
eq4 = sp.Eq(w.subs(x,L1),0)
eq5 = sp.Eq(phi.subs(x,L1),0)
sol = sp.solve([eq2,eq3,eq4,eq5],[C1,C2,C3,C4])
w_sol = w.subs(sol)
w_subs = w_sol.subs([(L1,10),(a,2),(EI,5000)])
display(sp.simplify(w_subs.rewrite(sp.Piecewise)))
V_inf_numpy = sp.lambdify([L1,a,EI,x],w_sol.rewrite(sp.Piecewise))

x_plot = np.linspace(0,10,1000)
plt.plot([0,10],[0,0],color='black',linewidth=2)
plt.plot(x_plot,V_inf_numpy(L1=10,a=2.5,EI=5000,x=x_plot),color="blue")
plt.xlabel('$x_F$')
plt.ylabel('Influence factor shear force')
axs = plt.gca()
axs.grid()
axs.invert_yaxis()
title0 = 'Influence line for shear force at $x_V = 2.5$'
axs.set_title(title0);
# Out:
# Piecewise((x**3/2000 - 3*x/20 + 1, x > 2), (x*(x**2 - 300)/2000, True))

# %% [markdown]
# ## Comparison V-line and influence line for shear force at $x = ...$ #

# %%
def func(a,b):
    x = np.linspace(0,10,200)
    fig, axs = plt.subplots(2, 1, figsize=(7, 6))
    axs[0].plot([0,10],[0,0],color='black',linewidth=2)
    axs[0].grid()
    axs[0].axis('equal')
    axs[0].plot(x,V_numpy(10,b,5000,x),color='blue')
    axs[0].plot(a,V_numpy(10,b,5000,a),marker='o')
    axs[0].annotate('%.2f kN' % V_numpy(10,b,5000,a),xy = [a,V_numpy(10,b,5000,a)+0.5])
    axs[0].annotate(text='', xy=(b,0), xytext=(b,-1), arrowprops=dict(arrowstyle='simple'))
    axs[0].invert_yaxis()
    title0 = 'Shear force distribution for force at $x_F = '+str(b)+'$, showing shear force at $x_V = '+str(a)+'$'
    axs[0].set_title(title0)
    axs[1].plot([0,10],[0,0],color='black',linewidth=2)
    axs[1].grid()
    axs[1].axis('equal')
    axs[1].plot(x,V_inf_numpy(10,a,5000,x),color='blue')
    axs[1].plot(b,V_inf_numpy(10,a,5000,b),marker='o')
    axs[1].annotate('%.2f kN' % V_inf_numpy(10,a,5000,b),xy = [b,V_inf_numpy(10,a,5000,b)+0.5])
    axs[1].invert_yaxis()
    title1 = 'Influence line for shear force at $x_V = '+str(a)+'$'
    axs[1].set_title(title1)
    
interact(func, a = widgets.FloatSlider(min=0, max=10, value=2, step=0.2, description="Location shear force $x_V$ = ... (m)",readout_format='.1f',style= {'description_width': '200px'},layout = {'width': '400px'}),
         b = widgets.FloatSlider(min=0, max=10, value=2, step=0.2, description="Location force $x_F$ = ... (m)",readout_format='.1f',style= {'description_width': '200px'},layout = {'width': '400px'}) );
# Out:
# interactive(children=(FloatSlider(value=2.0, description='Location shear force $x_V$ = ... (m)', layout=Layout…
